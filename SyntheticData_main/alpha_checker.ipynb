# %%
from SyntheticData_main.utils import *
import os
import cv2
import random
import numpy as np
from progressbar import ProgressBar
from other.parsing.train_args_parser import *
from other.losses_utils import ImageProcessor, DistanceCalculator
import torch
from SyntheticData_main.utils import FileManager, ImageUtils, ImageGeneratorUtils
from PIL import Image

# %%
import os
import numpy as np
from PIL import Image

def process_image(image_path):
    """
    Processes a single image to analyze its alpha channel.

    Args:
        image_path (str): The path to the image file.
    """
    with Image.open(image_path) as img:
        if img.mode in ('RGBA', 'LA') or ('transparency' in img.info):
            print(f"\nProcessing image: {image_path}")
            img_arr = np.array(img)
            if img_arr.ndim == 3 and img_arr.shape[2] >= 4:
                alpha = img_arr[:, :, 3]  # Extract the alpha channel
            else:
                print("Alpha channel not found in the image.")
                return

            total_pixels = alpha.size
            fully_opaque = np.sum(alpha == 255)  # Count fully opaque pixels
            non_zero = np.sum(alpha > 0)  # Count pixels with non-zero alpha
            print(f"Total alpha channel pixels: {total_pixels}")
            print(f"Fully opaque pixels (alpha == 255): {fully_opaque}")
            print(f"Non-zero alpha pixels (alpha > 0): {non_zero}")
        else:
            print(f"\nImage {image_path} does not contain an alpha channel.")

def process_directory(directory):
    """
    Processes all PNG images within a given directory and its subdirectories.

    Args:
        directory (str): The path to the directory containing images.
    """
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.png'):
                image_path = os.path.join(root, file)
                process_image(image_path)

if __name__ == '__main__':
    directory = r"C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj"
    # directory = r"C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Result\epoch19\label"
    process_directory(directory)
# Out:
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_0.png
# Total alpha channel pixels: 18144
# Fully opaque pixels (alpha == 255): 8810
# Non-zero alpha pixels (alpha > 0): 10536
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_1.png
# Total alpha channel pixels: 23436
# Fully opaque pixels (alpha == 255): 7959
# Non-zero alpha pixels (alpha > 0): 11531
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_10.png
# Total alpha channel pixels: 29988
# Fully opaque pixels (alpha == 255): 9052
# Non-zero alpha pixels (alpha > 0): 10788
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_11.png
# Total alpha channel pixels: 16632
# Fully opaque pixels (alpha == 255): 8411
# Non-zero alpha pixels (alpha > 0): 10093
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_12.png
# Total alpha channel pixels: 20412
# Fully opaque pixels (alpha == 255): 10424
# Non-zero alpha pixels (alpha > 0): 12025
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_13.png
# Total alpha channel pixels: 18825
# Fully opaque pixels (alpha == 255): 8839
# Non-zero alpha pixels (alpha > 0): 10107
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_14.png
# Total alpha channel pixels: 28476
# Fully opaque pixels (alpha == 255): 11328
# Non-zero alpha pixels (alpha > 0): 13353
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_15.png
# Total alpha channel pixels: 19404
# Fully opaque pixels (alpha == 255): 7899
# Non-zero alpha pixels (alpha > 0): 10337
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_16.png
# Total alpha channel pixels: 34272
# Fully opaque pixels (alpha == 255): 11744
# Non-zero alpha pixels (alpha > 0): 14106
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_17.png
# Total alpha channel pixels: 34524
# Fully opaque pixels (alpha == 255): 7022
# Non-zero alpha pixels (alpha > 0): 10993
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_18.png
# Total alpha channel pixels: 34020
# Fully opaque pixels (alpha == 255): 8314
# Non-zero alpha pixels (alpha > 0): 10610
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_19.png
# Total alpha channel pixels: 17892
# Fully opaque pixels (alpha == 255): 9252
# Non-zero alpha pixels (alpha > 0): 11017
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_2.png
# Total alpha channel pixels: 19656
# Fully opaque pixels (alpha == 255): 8626
# Non-zero alpha pixels (alpha > 0): 10011
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_20.png
# Total alpha channel pixels: 11718
# Fully opaque pixels (alpha == 255): 5170
# Non-zero alpha pixels (alpha > 0): 6484
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_21.png
# Total alpha channel pixels: 11970
# Fully opaque pixels (alpha == 255): 5470
# Non-zero alpha pixels (alpha > 0): 6840
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_22.png
# Total alpha channel pixels: 11430
# Fully opaque pixels (alpha == 255): 5066
# Non-zero alpha pixels (alpha > 0): 6712
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_23.png
# Total alpha channel pixels: 12222
# Fully opaque pixels (alpha == 255): 5673
# Non-zero alpha pixels (alpha > 0): 7386
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_24.png
# Total alpha channel pixels: 12446
# Fully opaque pixels (alpha == 255): 5253
# Non-zero alpha pixels (alpha > 0): 6203
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_25.png
# Total alpha channel pixels: 12008
# Fully opaque pixels (alpha == 255): 6660
# Non-zero alpha pixels (alpha > 0): 7555
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_26.png
# Total alpha channel pixels: 14896
# Fully opaque pixels (alpha == 255): 6885
# Non-zero alpha pixels (alpha > 0): 7947
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_27.png
# Total alpha channel pixels: 16568
# Fully opaque pixels (alpha == 255): 7829
# Non-zero alpha pixels (alpha > 0): 9109
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_28.png
# Total alpha channel pixels: 17784
# Fully opaque pixels (alpha == 255): 9265
# Non-zero alpha pixels (alpha > 0): 10560
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_29.png
# Total alpha channel pixels: 19026
# Fully opaque pixels (alpha == 255): 7373
# Non-zero alpha pixels (alpha > 0): 8607
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_3.png
# Total alpha channel pixels: 22680
# Fully opaque pixels (alpha == 255): 10769
# Non-zero alpha pixels (alpha > 0): 13177
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_4.png
# Total alpha channel pixels: 20664
# Fully opaque pixels (alpha == 255): 9592
# Non-zero alpha pixels (alpha > 0): 12369
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_5.png
# Total alpha channel pixels: 21924
# Fully opaque pixels (alpha == 255): 11116
# Non-zero alpha pixels (alpha > 0): 12996
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_6.png
# Total alpha channel pixels: 18396
# Fully opaque pixels (alpha == 255): 9407
# Non-zero alpha pixels (alpha > 0): 11076
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_7.png
# Total alpha channel pixels: 17136
# Fully opaque pixels (alpha == 255): 9027
# Non-zero alpha pixels (alpha > 0): 10569
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_8.png
# Total alpha channel pixels: 23436
# Fully opaque pixels (alpha == 255): 9946
# Non-zero alpha pixels (alpha > 0): 11560
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\1_9.png
# Total alpha channel pixels: 14364
# Fully opaque pixels (alpha == 255): 8327
# Non-zero alpha pixels (alpha > 0): 9570
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_0.png
# Total alpha channel pixels: 15840
# Fully opaque pixels (alpha == 255): 6517
# Non-zero alpha pixels (alpha > 0): 9310
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_1.png
# Total alpha channel pixels: 21090
# Fully opaque pixels (alpha == 255): 6844
# Non-zero alpha pixels (alpha > 0): 9350
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_10.png
# Total alpha channel pixels: 15987
# Fully opaque pixels (alpha == 255): 7196
# Non-zero alpha pixels (alpha > 0): 9221
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_11.png
# Total alpha channel pixels: 18122
# Fully opaque pixels (alpha == 255): 7671
# Non-zero alpha pixels (alpha > 0): 10772
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_12.png
# Total alpha channel pixels: 18920
# Fully opaque pixels (alpha == 255): 7074
# Non-zero alpha pixels (alpha > 0): 9879
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_13.png
# Total alpha channel pixels: 16060
# Fully opaque pixels (alpha == 255): 6405
# Non-zero alpha pixels (alpha > 0): 8930
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_14.png
# Total alpha channel pixels: 16863
# Fully opaque pixels (alpha == 255): 7842
# Non-zero alpha pixels (alpha > 0): 10053
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_15.png
# Total alpha channel pixels: 15456
# Fully opaque pixels (alpha == 255): 7290
# Non-zero alpha pixels (alpha > 0): 8798
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_16.png
# Total alpha channel pixels: 19227
# Fully opaque pixels (alpha == 255): 4778
# Non-zero alpha pixels (alpha > 0): 7733
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_17.png
# Total alpha channel pixels: 17617
# Fully opaque pixels (alpha == 255): 7367
# Non-zero alpha pixels (alpha > 0): 8957
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_18.png
# Total alpha channel pixels: 19980
# Fully opaque pixels (alpha == 255): 6855
# Non-zero alpha pixels (alpha > 0): 8978
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_19.png
# Total alpha channel pixels: 13098
# Fully opaque pixels (alpha == 255): 6849
# Non-zero alpha pixels (alpha > 0): 8363
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_2.png
# Total alpha channel pixels: 22321
# Fully opaque pixels (alpha == 255): 8264
# Non-zero alpha pixels (alpha > 0): 10317
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_20.png
# Total alpha channel pixels: 21408
# Fully opaque pixels (alpha == 255): 7257
# Non-zero alpha pixels (alpha > 0): 9418
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_21.png
# Total alpha channel pixels: 13481
# Fully opaque pixels (alpha == 255): 6675
# Non-zero alpha pixels (alpha > 0): 8652
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_22.png
# Total alpha channel pixels: 13640
# Fully opaque pixels (alpha == 255): 6419
# Non-zero alpha pixels (alpha > 0): 8113
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_23.png
# Total alpha channel pixels: 14960
# Fully opaque pixels (alpha == 255): 7785
# Non-zero alpha pixels (alpha > 0): 9363
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_24.png
# Total alpha channel pixels: 17459
# Fully opaque pixels (alpha == 255): 7279
# Non-zero alpha pixels (alpha > 0): 8860
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_25.png
# Total alpha channel pixels: 19710
# Fully opaque pixels (alpha == 255): 7284
# Non-zero alpha pixels (alpha > 0): 9110
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_26.png
# Total alpha channel pixels: 13320
# Fully opaque pixels (alpha == 255): 7401
# Non-zero alpha pixels (alpha > 0): 8798
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_27.png
# Total alpha channel pixels: 20424
# Fully opaque pixels (alpha == 255): 9308
# Non-zero alpha pixels (alpha > 0): 11314
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_28.png
# Total alpha channel pixels: 17538
# Fully opaque pixels (alpha == 255): 7398
# Non-zero alpha pixels (alpha > 0): 10345
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_29.png
# Total alpha channel pixels: 17958
# Fully opaque pixels (alpha == 255): 7863
# Non-zero alpha pixels (alpha > 0): 9644
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_3.png
# Total alpha channel pixels: 16350
# Fully opaque pixels (alpha == 255): 7423
# Non-zero alpha pixels (alpha > 0): 9195
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_30.png
# Total alpha channel pixels: 9768
# Fully opaque pixels (alpha == 255): 4893
# Non-zero alpha pixels (alpha > 0): 5587
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_31.png
# Total alpha channel pixels: 7437
# Fully opaque pixels (alpha == 255): 4373
# Non-zero alpha pixels (alpha > 0): 5139
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_32.png
# Total alpha channel pixels: 12543
# Fully opaque pixels (alpha == 255): 6182
# Non-zero alpha pixels (alpha > 0): 7254
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_33.png
# Total alpha channel pixels: 10670
# Fully opaque pixels (alpha == 255): 5896
# Non-zero alpha pixels (alpha > 0): 6811
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_34.png
# Total alpha channel pixels: 11978
# Fully opaque pixels (alpha == 255): 4369
# Non-zero alpha pixels (alpha > 0): 5238
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_35.png
# Total alpha channel pixels: 11704
# Fully opaque pixels (alpha == 255): 6169
# Non-zero alpha pixels (alpha > 0): 6792
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_36.png
# Total alpha channel pixels: 14580
# Fully opaque pixels (alpha == 255): 6970
# Non-zero alpha pixels (alpha > 0): 7832
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_37.png
# Total alpha channel pixels: 12635
# Fully opaque pixels (alpha == 255): 4987
# Non-zero alpha pixels (alpha > 0): 6004
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_38.png
# Total alpha channel pixels: 17280
# Fully opaque pixels (alpha == 255): 5973
# Non-zero alpha pixels (alpha > 0): 7334
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_39.png
# Total alpha channel pixels: 11748
# Fully opaque pixels (alpha == 255): 5834
# Non-zero alpha pixels (alpha > 0): 7059
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_4.png
# Total alpha channel pixels: 14520
# Fully opaque pixels (alpha == 255): 7274
# Non-zero alpha pixels (alpha > 0): 9054
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_5.png
# Total alpha channel pixels: 19448
# Fully opaque pixels (alpha == 255): 7703
# Non-zero alpha pixels (alpha > 0): 9561
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_6.png
# Total alpha channel pixels: 14960
# Fully opaque pixels (alpha == 255): 7237
# Non-zero alpha pixels (alpha > 0): 8945
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_7.png
# Total alpha channel pixels: 13923
# Fully opaque pixels (alpha == 255): 7077
# Non-zero alpha pixels (alpha > 0): 8660
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_8.png
# Total alpha channel pixels: 17459
# Fully opaque pixels (alpha == 255): 8788
# Non-zero alpha pixels (alpha > 0): 10632
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\2_9.png
# Total alpha channel pixels: 13140
# Fully opaque pixels (alpha == 255): 6394
# Non-zero alpha pixels (alpha > 0): 8306
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_0.png
# Total alpha channel pixels: 23142
# Fully opaque pixels (alpha == 255): 6450
# Non-zero alpha pixels (alpha > 0): 8287
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_1.png
# Total alpha channel pixels: 12586
# Fully opaque pixels (alpha == 255): 6307
# Non-zero alpha pixels (alpha > 0): 7906
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_2.png
# Total alpha channel pixels: 14200
# Fully opaque pixels (alpha == 255): 5551
# Non-zero alpha pixels (alpha > 0): 6798
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_3.png
# Total alpha channel pixels: 13467
# Fully opaque pixels (alpha == 255): 6045
# Non-zero alpha pixels (alpha > 0): 7257
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_4.png
# Total alpha channel pixels: 17889
# Fully opaque pixels (alpha == 255): 6551
# Non-zero alpha pixels (alpha > 0): 7974
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_5.png
# Total alpha channel pixels: 11716
# Fully opaque pixels (alpha == 255): 6165
# Non-zero alpha pixels (alpha > 0): 7421
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_6.png
# Total alpha channel pixels: 7446
# Fully opaque pixels (alpha == 255): 3201
# Non-zero alpha pixels (alpha > 0): 3775
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_7.png
# Total alpha channel pixels: 7920
# Fully opaque pixels (alpha == 255): 4327
# Non-zero alpha pixels (alpha > 0): 4725
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_8.png
# Total alpha channel pixels: 9840
# Fully opaque pixels (alpha == 255): 4805
# Non-zero alpha pixels (alpha > 0): 5517
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\3_9.png
# Total alpha channel pixels: 7749
# Fully opaque pixels (alpha == 255): 4639
# Non-zero alpha pixels (alpha > 0): 5150
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_0.png
# Total alpha channel pixels: 10725
# Fully opaque pixels (alpha == 255): 4222
# Non-zero alpha pixels (alpha > 0): 5494
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_1.png
# Total alpha channel pixels: 9412
# Fully opaque pixels (alpha == 255): 3770
# Non-zero alpha pixels (alpha > 0): 4834
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_2.png
# Total alpha channel pixels: 10920
# Fully opaque pixels (alpha == 255): 4410
# Non-zero alpha pixels (alpha > 0): 5358
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_3.png
# Total alpha channel pixels: 11880
# Fully opaque pixels (alpha == 255): 5375
# Non-zero alpha pixels (alpha > 0): 6581
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_4.png
# Total alpha channel pixels: 22806
# Fully opaque pixels (alpha == 255): 5255
# Non-zero alpha pixels (alpha > 0): 6500
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_5.png
# Total alpha channel pixels: 9180
# Fully opaque pixels (alpha == 255): 3660
# Non-zero alpha pixels (alpha > 0): 4667
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_6.png
# Total alpha channel pixels: 4278
# Fully opaque pixels (alpha == 255): 2399
# Non-zero alpha pixels (alpha > 0): 2747
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_7.png
# Total alpha channel pixels: 7626
# Fully opaque pixels (alpha == 255): 3513
# Non-zero alpha pixels (alpha > 0): 4069
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_8.png
# Total alpha channel pixels: 7684
# Fully opaque pixels (alpha == 255): 3301
# Non-zero alpha pixels (alpha > 0): 3875
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\4_9.png
# Total alpha channel pixels: 8436
# Fully opaque pixels (alpha == 255): 3486
# Non-zero alpha pixels (alpha > 0): 4078
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_0.png
# Total alpha channel pixels: 8150
# Fully opaque pixels (alpha == 255): 4295
# Non-zero alpha pixels (alpha > 0): 5169
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_1.png
# Total alpha channel pixels: 12558
# Fully opaque pixels (alpha == 255): 3908
# Non-zero alpha pixels (alpha > 0): 4880
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_2.png
# Total alpha channel pixels: 8910
# Fully opaque pixels (alpha == 255): 4249
# Non-zero alpha pixels (alpha > 0): 5168
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_3.png
# Total alpha channel pixels: 16640
# Fully opaque pixels (alpha == 255): 4222
# Non-zero alpha pixels (alpha > 0): 5445
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_4.png
# Total alpha channel pixels: 11988
# Fully opaque pixels (alpha == 255): 3483
# Non-zero alpha pixels (alpha > 0): 4342
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_5.png
# Total alpha channel pixels: 9177
# Fully opaque pixels (alpha == 255): 4882
# Non-zero alpha pixels (alpha > 0): 5571
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_6.png
# Total alpha channel pixels: 8881
# Fully opaque pixels (alpha == 255): 2786
# Non-zero alpha pixels (alpha > 0): 3371
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_7.png
# Total alpha channel pixels: 4284
# Fully opaque pixels (alpha == 255): 1758
# Non-zero alpha pixels (alpha > 0): 2212
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_8.png
# Total alpha channel pixels: 10098
# Fully opaque pixels (alpha == 255): 4852
# Non-zero alpha pixels (alpha > 0): 5674
#
# Processing image: C:\Users\Admin\PycharmProjects\PythonProject\Human-Segmentation-main\SyntheticData_main\Obj\5_9.png
# Total alpha channel pixels: 9270
# Fully opaque pixels (alpha == 255): 4451
# Non-zero alpha pixels (alpha > 0): 5135
